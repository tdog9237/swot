# %% [markdown]
# <a href="https://colab.research.google.com/github/tdog9237/swot/blob/master/Ollama_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Run Ollama in Colab
# ---
#
# [![5aharsh/collama](https://raw.githubusercontent.com/5aharsh/collama/main/assets/banner.png)](https://github.com/5aharsh/collama)
#
# This is an example notebook which demonstrates how to run Ollama inside a Colab instance. With this you can run pretty much any small to medium sized models offerred by Ollama for free.
#
# For the list of available models check [models being offerred by Ollama](https://ollama.com/library).
#
#
# ## Before you proceed
# ---
#
# Since by default the runtime type of Colab instance is CPU based, in order to use LLM models make sure to change your runtime type to T4 GPU (or better if you're a paid Colab user). This can be done by going to **Runtime > Change runtime type**.
#
# While running your script be mindful of the resources you're using. This can be tracked at **Runtime > View resources**.
#
# ## Running the notebook
# ---
#
# After configuring the runtime just run it with **Runtime > Run all**. And you can start tinkering around. This example uses [Llama 3.2](https://ollama.com/library/llama3.2) to generate a response from a prompted question using [LangChain Ollama Integration](https://python.langchain.com/docs/integrations/chat/ollama/).

# %% [markdown]
# ## Installing Dependencies
# ---
#
# 1. `pciutils` is required by Ollama to detect the GPU type.
# 2. Installation of Ollama in the runtime instance will be taken care by `curl -fsSL https://ollama.com/install.sh | sh`

# %%
# !sudo apt update
# !sudo apt install -y pciutils
# !curl -fsSL https://ollama.com/install.sh | sh

# %%
pip install xtts_api_server
# Out:
# Collecting xtts_api_server
#   Downloading xtts_api_server-0.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting coqui-tts==0.24.1 (from coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading coqui_tts-0.24.1-cp311-cp311-manylinux1_x86_64.whl.metadata (21 kB)
# Collecting cutlet (from xtts_api_server)
#   Downloading cutlet-0.5.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: fastapi>=0.104.1 in /usr/local/lib/python3.11/dist-packages (from xtts_api_server) (0.115.12)
# Collecting fugashi[unidic-lite] (from xtts_api_server)
#   Downloading fugashi-1.5.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.3 kB)
# Collecting loguru (from xtts_api_server)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting pyaudio==0.2.14 (from xtts_api_server)
#   Downloading PyAudio-0.2.14.tar.gz (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 2.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from xtts_api_server) (2.11.7)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from xtts_api_server) (0.25.1)
# Collecting python-dotenv (from xtts_api_server)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting pyttsx3==2.90 (from xtts_api_server)
#   Downloading pyttsx3-2.90-py3-none-any.whl.metadata (3.6 kB)
# Collecting requests==2.31.0 (from xtts_api_server)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting spacy==3.7.2 (from xtts_api_server)
#   Downloading spacy-3.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting stream2sentence==0.2.2 (from xtts_api_server)
#   Downloading stream2sentence-0.2.2-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from xtts_api_server) (2.6.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from xtts_api_server) (2.6.0+cu124)
# Collecting transformers==4.36.2 (from xtts_api_server)
#   Downloading transformers-4.36.2-py3-none-any.whl.metadata (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 4.8 MB/s eta 0:00:00
# Collecting uuid (from xtts_api_server)
#   Downloading uuid-1.30.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (from xtts_api_server) (0.34.3)
# Requirement already satisfied: numpy>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (2.0.2)
# Requirement already satisfied: cython>=0.29.30 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (3.0.12)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (1.15.3)
# Requirement already satisfied: soundfile>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (0.13.1)
# Requirement already satisfied: librosa>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (0.11.0)
# Requirement already satisfied: inflect>=5.6.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (7.5.0)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (4.67.1)
# Collecting anyascii>=0.3.0 (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (6.0.2)
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (2025.3.2)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (24.2)
# Collecting pysbd>=0.3.4 (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: umap-learn>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (0.5.7)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (3.10.0)
# Collecting coqui-tts-trainer>=0.1 (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading coqui_tts_trainer-0.3.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting coqpit>=0.0.16 (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading coqpit-0.0.17-py3-none-any.whl.metadata (11 kB)
# Collecting gruut==2.2.3 (from gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading gruut-2.2.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (0.8.1)
# Collecting encodec>=0.1.1 (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading encodec-0.1.1.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 49.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting num2words (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->xtts_api_server) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->xtts_api_server) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->xtts_api_server) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->xtts_api_server) (2025.6.15)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy==3.7.2->xtts_api_server) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy==3.7.2->xtts_api_server) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy==3.7.2->xtts_api_server) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy==3.7.2->xtts_api_server) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy==3.7.2->xtts_api_server) (3.0.10)
# Collecting thinc<8.3.0,>=8.1.8 (from spacy==3.7.2->xtts_api_server)
#   Downloading thinc-8.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy==3.7.2->xtts_api_server) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy==3.7.2->xtts_api_server) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy==3.7.2->xtts_api_server) (2.0.10)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy==3.7.2->xtts_api_server)
#   Downloading weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy==3.7.2->xtts_api_server)
#   Downloading typer-0.9.4-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy==3.7.2->xtts_api_server)
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy==3.7.2->xtts_api_server) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy==3.7.2->xtts_api_server) (75.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy==3.7.2->xtts_api_server) (3.5.0)
# Collecting nltk==3.8.1 (from stream2sentence==0.2.2->xtts_api_server)
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting emoji==2.8.0 (from stream2sentence==0.2.2->xtts_api_server)
#   Downloading emoji-2.8.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting stanza==1.6.1 (from stream2sentence==0.2.2->xtts_api_server)
#   Downloading stanza-1.6.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.36.2->xtts_api_server) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.36.2->xtts_api_server) (0.33.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.36.2->xtts_api_server) (2024.11.6)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.36.2->xtts_api_server)
#   Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.36.2->xtts_api_server) (0.5.3)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (2.17.0)
# Collecting dateparser~=1.1.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading dateparser-1.1.8-py2.py3-none-any.whl.metadata (27 kB)
# Collecting gruut-ipa<1.0,>=0.12.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading gruut-ipa-0.13.0.tar.gz (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 9.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_en~=2.0.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading gruut_lang_en-2.0.1.tar.gz (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 83.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jsonlines~=1.2.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading jsonlines-1.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting networkx<3.0.0,>=2.5.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading networkx-2.8.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting numpy>=1.24.3 (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.2 MB/s eta 0:00:00
# Collecting python-crfsuite~=0.9.7 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading python_crfsuite-0.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting gruut_lang_de~=2.0.0 (from gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading gruut_lang_de-2.0.1.tar.gz (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 108.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_es~=2.0.0 (from gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading gruut_lang_es-2.0.1.tar.gz (31.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_fr~=2.0.0 (from gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading gruut_lang_fr-2.0.2.tar.gz (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 125.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk==3.8.1->stream2sentence==0.2.2->xtts_api_server) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk==3.8.1->stream2sentence==0.2.2->xtts_api_server) (1.5.1)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza==1.6.1->stream2sentence==0.2.2->xtts_api_server) (5.29.5)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi>=0.104.1->xtts_api_server) (0.46.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi>=0.104.1->xtts_api_server) (4.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->xtts_api_server) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->xtts_api_server) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->xtts_api_server) (0.4.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->xtts_api_server)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->xtts_api_server)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->xtts_api_server)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->xtts_api_server)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->xtts_api_server)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->xtts_api_server)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->xtts_api_server)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->xtts_api_server)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->xtts_api_server)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->xtts_api_server) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->xtts_api_server) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->xtts_api_server) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->xtts_api_server)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->xtts_api_server) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->xtts_api_server) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->xtts_api_server) (1.3.0)
# Collecting jaconv (from cutlet->xtts_api_server)
#   Downloading jaconv-0.4.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting mojimoji (from cutlet->xtts_api_server)
#   Downloading mojimoji-0.0.13-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Collecting unidic-lite (from fugashi[unidic-lite]->xtts_api_server)
#   Downloading unidic-lite-1.0.8.tar.gz (47.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 19.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn->xtts_api_server) (0.16.0)
# Collecting coqpit-config<0.3.0,>=0.2.0 (from coqui-tts-trainer>=0.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading coqpit_config-0.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.11/dist-packages (from coqui-tts-trainer>=0.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (5.9.5)
# Requirement already satisfied: tensorboard>=2.17.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts-trainer>=0.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (2.18.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (3.11.15)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.2->xtts_api_server) (1.1.3)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.11/dist-packages (from inflect>=5.6.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (10.7.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from inflect>=5.6.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (4.4.3)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy==3.7.2->xtts_api_server) (1.3.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (1.6.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (1.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (2.9.0.post0)
# Collecting docopt>=0.6.2 (from num2words->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (1.17.1)
# Collecting sudachipy!=0.6.1,>=0.5.2 (from spacy[ja]>=3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading SudachiPy-0.6.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting sudachidict-core>=20211220 (from spacy[ja]>=3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading sudachidict_core-20250515-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.47.0,>=0.40.0->fastapi>=0.104.1->xtts_api_server) (4.9.0)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.1.8->spacy==3.7.2->xtts_api_server)
#   Downloading blis-0.7.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.1.8->spacy==3.7.2->xtts_api_server) (0.1.5)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (0.5.13)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy==3.7.2->xtts_api_server)
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Collecting bangla (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading bangla-0.0.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting bnnumerizer (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading bnnumerizer-0.0.2.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bnunicodenormalizer (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading bnunicodenormalizer-0.1.7-py3-none-any.whl.metadata (22 kB)
# Collecting mecab-python3 (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading mecab_python3-1.0.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting hangul-romanize (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading hangul_romanize-0.1.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting jamo (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting g2pkk>=0.1.1 (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading g2pkk-0.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: jieba in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (0.42.1)
# Collecting pypinyin (from coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server)
#   Downloading pypinyin-0.54.0-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy==3.7.2->xtts_api_server) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (1.20.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi>=0.104.1->xtts_api_server) (1.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.0->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (2.22)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from dateparser~=1.1.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (2025.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.11/dist-packages (from dateparser~=1.1.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (5.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from jsonlines~=1.2.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (1.17.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy==3.7.2->xtts_api_server) (1.2.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa>=0.10.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa>=0.10.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (4.3.8)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa>=0.10.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (3.6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer>=0.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer>=0.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (1.73.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer>=0.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer>=0.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer>=0.1->coqui-tts==0.24.1->coqui-tts[languages]==0.24.1->xtts_api_server) (3.1.3)
# Downloading xtts_api_server-0.9.0-py3-none-any.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.9/148.9 kB 13.5 MB/s eta 0:00:00
# Downloading coqui_tts-0.24.1-cp311-cp311-manylinux1_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 72.4 MB/s eta 0:00:00
# Downloading pyttsx3-2.90-py3-none-any.whl (39 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 5.8 MB/s eta 0:00:00
# Downloading spacy-3.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 107.4 MB/s eta 0:00:00
# Downloading stream2sentence-0.2.2-py3-none-any.whl (6.7 kB)
# Downloading transformers-4.36.2-py3-none-any.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 120.9 MB/s eta 0:00:00
# Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 28.2 MB/s eta 0:00:00
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 73.3 MB/s eta 0:00:00
# Downloading stanza-1.6.1-py3-none-any.whl (881 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 50.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 664.8/664.8 MB 110.0 MB/s eta 0:00:01

# %% [markdown]
# ## Running Ollama
# ---
#
# In order to use Ollama it needs to run as a service in background parallel to your scripts. Becasue Jupyter Notebooks is built to run code blocks in sequence this make it difficult to run two blocks at the same time. As a workaround we will create a service using subprocess in Python so it doesn't block any cell from running.
#
# Service can be started by command `ollama serve`.
#
# `time.sleep(5)` adds some delay to get the Ollama service up before downloading the model.

# %%
import threading
import subprocess
import time

def run_ollama_serve():
  subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()
time.sleep(5)

# %% [markdown]
# ## Pulling Model
# ---
#
# Download the LLM model using `ollama pull llama3.2`.
#
# For other models check https://ollama.com/library

# %%
# !ollama pull llama3.2

# %% [markdown]
# ## And that's it!
# ---
#
# With this you should be able to freely play around with the models in your scripts. Following is an example using `langchain-ollama` to answer a simple prompt.
#
# If you have a use-case that can help out others feel free to add your notebook to [Collama](https://github.com/5aharsh/collama/fork)

# %%
# !pip install langchain-ollama

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM
from IPython.display import Markdown

template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="llama3.2")

chain = prompt | model

display(Markdown(chain.invoke({"question": "What's the length of hypotenuse in a right angled triangle"})))
